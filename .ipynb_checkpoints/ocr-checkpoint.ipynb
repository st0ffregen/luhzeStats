# %%
import os
from PIL import Image
from pdf2image import convert_from_path
import pytesseract
import numpy as np

# %%
filePath = '../print/pdfs/April2002.pdf'
doc = convert_from_path(filePath)
path, fileName = os.path.split(filePath)
fileBaseName, fileExtension = os.path.splitext(fileName)

# %%
len(doc)
# Out:
# 16

# %%
for page_number, page_data in enumerate(doc):
    if page_number == 3:
        page_image = Image.fromarray(np.array(page_data))
        txt = pytesseract.image_to_string(page_image, lang='deu')
        print(txt)
        break
# Out:
#
#
#
#
# Mei
#
# student!
#
# April 2002
#
#
#
# MEINUNGEN
#
# Es besteht kein Anspruch
# auf Abdruck eines Leser-
# briefes. Die student!-Re-
# daktion behält sich auch das
# Recht auf Kürzung vor.
# Auslassungen werden aber
# durch Punkte kenntlich ge-
# macht. Gekürzte Zuschriften
# bedürfen nicht der Autori-
# sierung. Wenn ihr uns per
# Mail die Meinung sagen
# wollt, dann schreibt bitte an
# meinung@student-leipzig.de!
#
# Frauen in Blei
# gegossen
#
# zu Thema-Seiten Frauen an der
# Uni in student! 11/01
#
# Hi, also der Ansatz der Themen-
# seite war ja nicht schlecht aber
# trockener ging es wohl nicht. Den
# Schreibstil der Leute hat man
# wohl vorher in Blei gegossen?
# (...) Sonst aber macht auf jeden
# Fall weiter, meine Kritik soll keine
# vernichtende sein.
#
# Salman Kanduzar
#
# Unvollständiges
# Bild
#
# aber wo?” in
#
# zu: “Schwul,
# student! 01/02
#
# Hallo TD,
# dieser Artikel in der Student war
# ja wirklich sehr erheiternd, ob-
# wohl einige der Scherzchen etwas
# auf Kosten der Tatsachen gehen.
# Zwar finde ich die Beschreibung
# der „Blauen Trude” leicht über-
# zogen und aber trotzdem sehr
# zutreffend (...). Klar, größtenteils
# abgefahrene „Party-Gays” (...),
# aber die passen eigentlich nicht
# ins Publikum der
# Möglichkeiten.
#
#
#
# anderen
#
# Was mich dazu bringt anzumer-
# ken, sehr wichtige
# einfach ignoriert wurde, nämlich
# die wsalinde e.V. (Brühl 20). Die
# Rosalinde möchte den Schwulen
# und Lesben in Leipzig mehr
# bieten als einfach nur ein ver-
#
# dass eine
#
# rottetes Plätzchen zum abhäng-
# en, oder eine dunkle Ecke zum
# rumfummeln. Als gemeinnütziger
# Verein (...) unterstützt sie
# Schwullesbische Projekte, kul-
# turelle Angebote und bietet einen
# Treffpunkt (Disko/ Cafe...) für
# Schwule und Lesben an.
#
#
#
#
#
# Der Artikel ist joumnalistisch ge-
# sehen nicht objektiv. Der Sarkas-
# mus und Humor reflektiert wirk-
# Szene,
# bietet aber ein unvollständiges
# Bild. Viele können sich mit den so
# genannten Kneipen und Diskos
# nicht identifizieren oder wollen
# sich nicht anpassen. Für diese ist
# die AG Hochschwul wie auch die
# Rosalinde eine gute Möglichkeit
# Menschen kennen zu lernen,
# schwul wegzugehen, Angebote zu
# veranstalten,
# aufzubauen und
# zu vertreten. (...)
#
# lich unterhaltsam die
#
# Selbstbewusstsein
# ihre Interessen
#
# vincenz
#
# Peinliches Duell
#
# jeit fast einem Jahrzehnt streitet
#
# Leipzig über die geeignete Form
# des Erinnerns. Es geht um den
# Wiederaufbau einer Kirche, die 1968
# unter Walter Ulbrichts Aufsicht ge-
# sprengt worden ist. Die von langer
# Hand geplante, mutwillige Zerstö-
# rung der Paulinerkirche war ein
# trauriger Höhepunkt der antibürger-
# lichen Kulturpolitik der DDR. Mit der
# Sprengung ging nicht nur ein
# Jahrhunderte Jahre
# Kulturgut verloren - dem Widerstand
# im SED-Staat
# weitere
#
# altes altes
#
# wurde auch eine
# Rückzugmöglichkeit
# genommen. Stoff genug heute, nach
# der Wiedervereinigung,
# Reflexion über begangenes Unrechts
# sozialistischen Teil
#
# Stoff genug offen-
#
# für eine
#
# im ehemals
# Deutschlands.
#
# sichtlich auch für einen Kleinkrieg,
# der alle Anzeichen von verkrustetem
# Demokratieverständnis aufweist.
#
# Vor allem seit im vergangenem
# Jahr ein Architektenwettbewerb aus-
# ist, schießen die
# Wort-Kanonen. Der Paulinerverein,
# 350-Mann-Lobby, besteht
# darauf, dass nur eine originalgetreu
#
# gelobt worden
# eine
#
# wiederaufgebaute Kopie die Spren-
# gung von 1968 adäquat erinnern
# könne.
#
# Die Universität, Bauträger des
# Areals am Augustusplatz, das Land
# Stadt Leipzig
# hingegen pochen auf eine zeitge-
# mäße Bebauung, die in abstrakter
# Art und Weise an die „nicht wieder-
# gutzumachende Schande” erinnert.
# Es ist die Frage, wie erinnert werden
#
# Sachsen und die
#
# kann, die den Streit über Jahre
# schwelen ließ. Es ist eine schwierige
# Frage, gewiss, die nun auf demokra-
# tischem Wege geführt werden muss.
# Deshalb hilft es wenig, wenn sich
# beide Seiten gegenseitig Fanatismus
# oder totalitäre Tendenzen in der
# Argumentation vorwerfen. Vor allem
# das Argument aufseiten des Pauli-
# nervereins, wer die Rekonstruktion
# nicht wolle, habe die Sprengung
# gewollt, ist wenig fruchtbar. Um sich
# später an das wahre Unrecht, das der
# Sprengung zu erinnern, bedarf es
# einer Diskussion, in der sich beide
# Seiten ernst nehmen. Sonst werden
# sich spätere Generationen nur an das
# peinliche Duell einer alternden Garde
# Anja Mutschler
#
# (Seite 3)
#
# erinnern.
#
#
#
#
#
#
#
# x
#
# SGntr
#
#
#
#
#
#
#
# Wers rauskriegt bekommt einen Lolli!!!! Lösung an: meinung®@ student-leipzig.de
#
# Ss im Mai soll der Tier-
# schutz ins Grundgesetz ge-
# schrieben werden. So wollen es
# die Berliner Parteien. Die
# Hochschulrektorenkonferenz
# ist dagegen. student! druckt
# eine gekürzte Fassung ihrer
# Erklärung.
#
# Dem Schutz von Tieren wissen sich
# Hochschulen und Forschungseinrich-
# tungen verpflichtet. Die Hoch-
# schulen handeln entsprechend den
# Vorschriften des
# schutzgesetzes, das zu den strengs-
# ten der Welt gehört. Durch Einhal-
# tung des Tierschutzgesetzes wird ein
# wirksamer Tierschutz gewährleistet.
# In den Hochschulen wurden und
#
# deutschen Tier-
#
# werden „alternative Verfahren” für
# Forschung und Lehre entwickelt, um
# Untersuchungen an lebenden Tieren
# auf das notwendigste zu reduzieren.
#
#
#
# Deutschen Bundestag diskutierte
# Verankerung des Tierschutzes als
# Staatsziel im Grundgesetz würde in
# Hochschulen und Forschungsein-
# richtungen Lehre und Forschung in
# nicht hinzunehmender Weise be-
# einträchtigen und könnte diejenigen
# ermutigen, die verantwortungsvolle
# Wissenschaftler in unerträglicher
#
# Zeit die im Interesse menschlicher
# Gesundheit notwendige, auch mit
# Tierversuchen verbundene,
# nische und biologische Forschung in
# Deutschland zum Eiliegen bringen
# ins Ausland verlagern. Die
# Wettbewerbsfähigkeit von großen
# Teilen der
#
# Forschung und der Unternehmen
#
# medizi-
#
# und
#
# biomedizinischen
#
#
#
# „Hochschulen forschen für den
# Tierschutz”
#
# Weise diffamieren und bedrohen.
#
# Die nach einer Verankerung eines
# notwendigerweise pauschalen
# Staatszieles „Merschutz” zu erwar-
# tenden Klagen von Tierschutzorga-
#
# Hochschulrektorenkonferenz
#
# dieser Branchen wäre dann nicht
# gegeben. Die
# Hochschulrektorenkonferenz
#
# mehr
#
# appelliert deshalb an Bundestag und
#
# Bundesrat, von einer Aufnahme
#
# Auch betreiben Hochschulen nisationen würden in der Praxis zu eines Staatsziels Tierschutz in das
# Forschung und Lehre zur Förderung Frage- und Forschungsverboten Grundgesetz abzusehen.
# des Tierschutzes. Die derzeit im führen. Sie würden binnen kurzer (Seite 5)
# x x Leserbriefe & Meinungen bitte an: meinung@student-leipzig.de
#
# Die Ressorts erreicht ihr: politik, lifestyle, service, kultur, umwelt, visuelles,
#
#
#
# thema, kleinanzeigen, chefredaktion und dann einfach @student-leipzig.de
#
# MEINUNGEN
#
# Sieg auf dem
# Speisenplan
# zu: *06H6(16” in student! 01/02
# Sehr geehrtes Redaktionsteam,
#
# nach dem zweifelhaften Editorial
# Februarausgabe Eurer
# Zeitung über das Engagement des
# RCDS Leipzig mache ich hiermit
# darauf aufamerksam, dass sich die
# Bemühungen des RCDS um an-
# gemessene Mensapreise durchaus
# gelohnt haben.
# Ayer-Aktion Anfang Januar und
# einem Gespräch mit den Ver-
# Studenten-
# werks wurde zumindest das Essen
# A wieder verbilligt! (...) Damit ist
# zumindest die üppigste Preiser-
# höhung rückgängig gemacht
# worden.
#
# in der
#
# Nach unserer
#
# antwortlichen des
#
# In einer entsprechenden Mit-
# teilung des Studenenwerkes im
# aktuellen Speiseplan ist zu lesen:
# „In Gesprächen mit Studierenden
# hat sich nun gezeigt,
# wichtiger erscheint, den Preis für
# Essen A niedrig zu halten und den
# Preisunterschied von Essen A und
#
# dass es
#
# Essen B deutlich ausfallen zu
# lassen (...)”.
#
# In diesem Zusammenhang möchte
# ich darauf hinweisen, dass nur
# mangelhafte journalistische Sorg-
# falt zu Eurem Eindruck geführt
# haben kann, der RCDS würde sich
# „Neben-
# sächlichkeiten” widmen. (...)
#
# ausschließlich solchen
#
# Es stimmt zwar, dass wir nicht mit
# platten Parolen demonstrierend
# durch die Leipziger Innenstadt
# ziehen, allerdings solltet Ihr
# gerade deshalb einmal beim
# sächsischen Ministerpräsidenten,
# beim Staatsminister für Wissen-
# schaft und Kunst oder der CDU-
# Fraktion im Sächsischen Landtag
# (2. B. bei Herrn Dr. Grüning) nach-
# fragen,
# Gruppen tatsächlich an der
# Abmilderung der Görlitzer Be-
# schlüsse im letzten Jahr beteiligt
# waren...
#
# welche studentischen
#
# Eurer
# wenn Ihr die
#
# Im übrigen stände es
# Zeitung gut an,
# wirklich heißen Eisen auch einmal
# anpacken würdet. Vom Finanz-
# skandal im Leipziger StuRa
# scheint Ihr ja überhaupt nichts
# mitbekommen zu haben.
#
# Sven Petermann
# RCDS Leipzig
#
# Keinen
# Hunger?
#
# zu: *06H6C16” in student! 01/02
#
# Die Stellenkürzungen betreffen in
# jedem Fall mehr Studenten, denn
# wenn das Essen in der Mensa zu
# teuer wird, gibt es ja genug
# andere Alternativen. Das müßte
# das Studentenwerk ja wissen.
# Denen wird das aber eh egal sein,
# da die ja von unseren Semester-
# beitrag leben.
#
# Thomas Reuer

# %%
import sys
print(sys.version)
# Out:
# 3.9.2 (default, Feb 28 2021, 17:03:44)
# [GCC 10.2.1 20210110]

# %% [markdown]
# # Problems
# * recognize an article with start and end
# * recognize article's author
